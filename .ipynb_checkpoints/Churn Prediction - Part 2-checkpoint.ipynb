# %% [markdown]
# # Churn prediction for an energy company 🔌💡
# ## Part 2 - Data Exploration and Feature Engineering
# ### Importing packages and data

# %%
from utils import *

repo_path = "/workspaces/churn-prediction-storage/energy-churn-prediction"

client_file_path = f"{repo_path}/data/client_data_cleaned.csv"
client_date_cols = ['date_activ', 'date_modif_prod', 'date_renewal', 'date_end']

price_file_path = f"{repo_path}/data/price_data_cleaned.csv"
price_date_col = 'price_date'

# Load the data and convert datetime columns
client_df = load_and_convert_datetime(client_file_path, client_date_cols)
price_df = load_and_convert_datetime(price_file_path, [price_date_col])

# %% [markdown]
# ### Imputing missing price values

# %% [markdown]
# Let's start with `price_df`, and let's have a look at the distinct values of `price_date` variable and at the number of unique IDs contained in this table:

# %%
print(f"Number of unique IDs: {price_df['id'].nunique()}")
print("\n------------------------------------------------\n")
print("Distinct values of the 'price_date' variable:")
price_df[price_date_col].value_counts().sort_index()
# Out:
# Number of unique IDs: 16096
#
# ------------------------------------------------
#
# Distinct values of the 'price_date' variable:
# price_date
# 2015-01-01    16070
# 2015-02-01    16082
# 2015-03-01    16074
# 2015-04-01    16079
# 2015-05-01    16080
# 2015-06-01    16085
# 2015-07-01    16090
# 2015-08-01    16094
# 2015-09-01    16082
# 2015-10-01    16085
# 2015-11-01    16087
# 2015-12-01    16094
# Name: count, dtype: int64

# %% [markdown]
# From the information above, we can infer that this table provides information on price values from January to December 2015 for 16096 customers. However, it seems that there are some missing values here and there for some IDs:

# %%
row_counts = price_df.groupby('id').size().reset_index(name='row_count_per_id')

plot_bar_charts(row_counts, ['row_count_per_id'])

# %% [markdown]
# It has been decided to impute these missing values with the monthly medians:

# %%
price_numeric_cols = price_df.select_dtypes(include=['number']).columns

incomplete_clients = row_counts[row_counts['row_count_per_id'] < 12]["id"]

# Generate a complete date range for each client
date_range = pd.date_range(start="2015-01-01", periods=12, freq='MS')
dates_df = pd.DataFrame({price_date_col: date_range})

# Create complete combinations of client_id and months
all_combinations = (
    incomplete_clients.to_frame()
    .merge(dates_df, how="cross")
    .rename(columns={"id": "client_id"})
)

# Merge with existing data to find missing records
merged_data = (
    all_combinations.merge(
        price_df, left_on=["client_id", price_date_col], right_on=["id", price_date_col], how="left"
    )
    .drop(columns=["id"])
    .rename(columns={"client_id": "id"})
)

# Filter rows where any price variable is missing
missing_rows = merged_data[merged_data[price_numeric_cols].isnull().any(axis=1)]

# Step 5: Compute monthly medians
monthly_medians = price_df.groupby(price_date_col)[price_numeric_cols].median().reset_index()

# Step 6: Impute missing values
missing_rows = missing_rows.merge(monthly_medians, on=price_date_col, suffixes=("", "_Median"))

for col in price_numeric_cols:
    missing_rows[col] = missing_rows[col].fillna(missing_rows[f"{col}_Median"])
    missing_rows.drop(columns=[f"{col}_Median"], inplace=True)

# Concatenate imputed rows with original dataset
price_df = pd.concat([price_df, missing_rows], ignore_index=True)

# Ensure no missing values remain
print("Final Missing Values Check:")
print(price_df.isnull().sum())
# Out:
# Final Missing Values Check:
# id                    0
# price_date            0
# price_off_peak_var    0
# price_peak_var        0
# price_mid_peak_var    0
# price_off_peak_fix    0
# price_peak_fix        0
# price_mid_peak_fix    0
# dtype: int64

# %% [markdown]
# ### Computing summary statistics for price trends

# %% [markdown]
# Let's have a look at the trends for the 6 price variables, by plotting both the average trend and the individual trends for a randomly chosen sample of 100 IDs:

# %%
plot_price_trends(price_df, price_numeric_cols, price_date_col, 'id', n_sample=100)

# %% [markdown]
# As you can see, while many of the individual trends appear almost constant, some exhibit spikes or troughs. To summarize these trends for joining with the `client_df`, several price features have been engineered, including those capturing these kinds of irregularities, such as the maximum difference between two consecutive months for each customer.

# %%
price_df = price_df.sort_values(by=['id', price_date_col])

# Group by 'id'
grouped_df = price_df[['id']+price_numeric_cols.tolist()].groupby('id')

# Compute statistics
mean_df = grouped_df.mean()
median_df = grouped_df.median()
min_df = grouped_df.min()
max_df = grouped_df.max()
std_df = grouped_df.std()
max_diff_df = grouped_df.agg(lambda x: max(x.iloc[i+1] - x.iloc[i] for i in range(len(x)-1)))

# Rename columns for clarity
mean_df.columns = [f"{col}_mean" for col in price_numeric_cols]
median_df.columns = [f"{col}_median" for col in price_numeric_cols]
min_df.columns = [f"{col}_min" for col in price_numeric_cols]
max_df.columns = [f"{col}_max" for col in price_numeric_cols]
std_df.columns = [f"{col}_std" for col in price_numeric_cols]
max_diff_df.columns = [f"{col}_max_diff" for col in price_numeric_cols]

# Join all DataFrames on 'id'
price_summary_df = pd.concat([mean_df, min_df, max_df, std_df, max_diff_df], axis=1)

# Reset index for a cleaner DataFrame if needed
price_summary_df.reset_index(inplace=True)

price_summary_df
# Out:
#                                      id  price_off_peak_var_mean  \
# 0      0002203ffbb812588b632b9e628cc38d                 0.124338
# 1      0004351ebdd665e6ee664792efc4fd13                 0.146426
# 2      0010bcc39e42b3c2131ed2ce55246e3c                 0.181558
# 3      0010ee3855fdea87602a5b7aba8e42de                 0.118757
# 4      00114d74e963e47177db89bc70108537                 0.147926
# ...                                 ...                      ...
# 16091  ffef185810e44254c3a4c6395e6b4d8a                 0.138863
# 16092  fffac626da707b1b5ab11e8431a4d0a2                 0.147137
# 16093  fffc0cacd305dd51f316424bbb08d1bd                 0.153879
# 16094  fffe4f5646aa39c7f97f95ae2679ce64                 0.123858
# 16095  ffff7fa066f1fb305ae285bb03bf325a                 0.125360
#
#        price_peak_var_mean  price_mid_peak_var_mean  price_off_peak_fix_mean  \
# 0                 0.103794                 0.073160                40.701732
# 1                 0.000000                 0.000000                44.385450
# 2                 0.000000                 0.000000                45.319710
# 3                 0.098292                 0.069032                40.647427
# 4                 0.000000                 0.000000                44.266930
# ...                    ...                      ...                      ...
# 16091             0.115125                 0.080780                40.896427
# 16092             0.000000                 0.000000                44.311375
# 16093             0.129497                 0.094842                41.160171
# 16094             0.103499                 0.073735                40.606699
# 16095             0.104895                 0.075635                40.647427
#
#        price_peak_fix_mean  price_mid_peak_fix_mean  price_off_peak_var_min  \
# 0                24.421038                16.280694                0.119906
# 1                 0.000000                 0.000000                0.143943
# 2                 0.000000                 0.000000                0.150837
# 3                24.388455                16.258971                0.113068
# 4                 0.000000                 0.000000                0.145440
# ...                    ...                      ...                     ...
# 16091            24.637456                16.507972                0.112488
# 16092             0.000000                 0.000000                0.144363
# 16093            24.895768                16.763569                0.151399
# 16094            24.364017                16.242678                0.118175
# 16095            24.388455                16.258971                0.119916
#
#        price_peak_var_min  price_mid_peak_var_min  ...  \
# 0                0.101673                0.070232  ...
# 1                0.000000                0.000000  ...
# 2                0.000000                0.000000  ...
# 3                0.095385                0.068646  ...
# 4                0.000000                0.000000  ...
# ...                   ...                     ...  ...
# 16091            0.094804                0.068829  ...
# 16092            0.000000                0.000000  ...
# 16093            0.126871                0.091394  ...
# 16094            0.100491                0.073433  ...
# 16095            0.102232                0.075004  ...
#
#        price_mid_peak_var_std  price_off_peak_fix_std  price_peak_fix_std  \
# 0                    0.001368            6.341481e-02            0.038049
# 1                    0.000000            8.753223e-02            0.000000
# 2                    0.000000            7.723930e-01            0.000000
# 3                    0.000403            8.507958e-02            0.051048
# 4                    0.000000            5.908392e-07            0.000000
# ...                       ...                     ...                 ...
# 16091                0.012503            1.749923e-01            0.209025
# 16092                0.000000            8.040373e-02            0.000000
# 16093                0.004310            8.491973e-02            0.051364
# 16094                0.000471            7.368063e-02            0.044209
# 16095                0.000659            8.507958e-02            0.051048
#
#        price_mid_peak_fix_std  price_off_peak_var_max_diff  \
# 0                    0.025366                     0.001969
# 1                    0.000000                     0.000358
# 2                    0.000000                     0.052694
# 3                    0.034032                     0.000000
# 4                    0.000000                     0.000468
# ...                       ...                          ...
# 16091                0.226040                     0.002317
# 16092                0.000000                     0.000684
# 16093                0.034586                     0.004084
# 16094                0.029474                     0.000000
# 16095                0.034032                     0.000000
#
#        price_peak_var_max_diff  price_mid_peak_var_max_diff  \
# 0                     0.001867                     0.003541
# 1                     0.000000                     0.000000
# 2                     0.000000                     0.000000
# 3                     0.000000                     0.000817
# 4                     0.000000                     0.000000
# ...                        ...                          ...
# 16091                 0.002317                     0.002317
# 16092                 0.000000                     0.000000
# 16093                 0.002317                     0.002317
# 16094                 0.000000                     0.001083
# 16095                 0.000000                     0.001307
#
#        price_off_peak_fix_max_diff  price_peak_fix_max_diff  \
# 0                         0.162916                 0.097749
# 1                         0.177779                 0.000000
# 2                         1.500000                 0.000000
# 3                         0.162912                 0.097752
# 4                         0.000000                 0.000000
# ...                            ...                      ...
# 16091                     0.000000                 0.000005
# 16092                     0.177780                 0.000000
# 16093                     0.164916                 0.099749
# 16094                     0.162912                 0.097752
# 16095                     0.162912                 0.097752
#
#        price_mid_peak_fix_max_diff
# 0                         0.065166
# 1                         0.000000
# 2                         0.000000
# 3                         0.065172
# 4                         0.000000
# ...                            ...
# 16091                     0.000002
# 16092                     0.000000
# 16093                     0.067166
# 16094                     0.065172
# 16095                     0.065172
#
# [16096 rows x 31 columns]

# %% [markdown]
# ### Merging the 2 tables

# %% [markdown]
# Before analyzing the distribution of these numeric variables, let's perform an inner join `price_summary_df` with `client_df`:

# %%
# Perform an inner join based on 'id'
merged_df = pd.merge(client_df, price_summary_df, on='id', how='inner')

merged_df
# Out:
#                                      id    channel_sales  cons_12m  \
# 0      24011ae4ebbe3035111d65fa7c15bc57        Channel 1         0
# 1      d29c2c54acc38ff3c0614d0a653813dd  Channel Missing      4660
# 2      764c75f661154dac3a6c254cd082ea7d        Channel 1       544
# 3      bba03439a292a1e166f80264c16191cb        Channel 2      1584
# 4      149d57cf92fc41cf94415803a877cb4b  Channel Missing      4425
# ...                                 ...              ...       ...
# 14524  18463073fb097fc0ac5d3e040f356987        Channel 1     32270
# 14525  d0a6f71671571ed83b2645d23af6de00        Channel 1      7223
# 14526  10e6828ddd62cbcf687cb74928c4c2d2        Channel 1      1844
# 14527  1cf20fd6206d7678d5bcafd28c53b4db        Channel 1       131
# 14528  563dde550fd624d7352f3de77c0cdfcd  Channel Missing      8730
#
#        cons_gas_12m  cons_last_month date_activ   date_end date_modif_prod  \
# 0             54946                0 2013-06-15 2016-06-15      2015-11-01
# 1                 0                0 2009-08-21 2016-08-30      2009-08-21
# 2                 0                0 2010-04-16 2016-04-16      2010-04-16
# 3                 0                0 2010-03-30 2016-03-30      2010-03-30
# 4                 0              526 2010-01-13 2016-03-07      2010-01-13
# ...             ...              ...        ...        ...             ...
# 14524         47940                0 2012-05-24 2016-05-08      2015-05-08
# 14525             0              181 2012-08-27 2016-08-27      2012-08-27
# 14526             0              179 2012-02-08 2016-02-07      2012-02-08
# 14527             0                0 2012-08-30 2016-08-30      2012-08-30
# 14528             0                0 2009-12-18 2016-12-17      2009-12-18
#
#       date_renewal  forecast_cons_12m  ...  price_mid_peak_var_std  \
# 0       2015-06-23               0.00  ...                0.020983
# 1       2015-08-31             189.95  ...                0.000000
# 2       2015-04-17              47.96  ...                0.000000
# 3       2015-03-31             240.04  ...                0.000000
# 4       2015-03-09             445.75  ...                0.001588
# ...            ...                ...  ...                     ...
# 14524   2014-05-26            4648.01  ...                0.000000
# 14525   2015-08-28             631.69  ...                0.000128
# 14526   2015-02-09             190.39  ...                0.001368
# 14527   2015-08-31              19.34  ...                0.000000
# 14528   2015-12-21             762.41  ...                0.000000
#
#        price_off_peak_fix_std  price_peak_fix_std  price_mid_peak_fix_std  \
# 0                1.050136e+00            7.039226                4.692817
# 1                8.040385e-02            0.000000                0.000000
# 2                8.753223e-02            0.000000                0.000000
# 3                8.040349e-02            0.000000                0.000000
# 4                7.368135e-02            0.044209                0.029473
# ...                       ...                 ...                     ...
# 14524            9.154352e-02            0.000000                0.000000
# 14525            1.165389e-01            0.071868                0.016479
# 14526            6.341481e-02            0.038049                0.025366
# 14527            8.040379e-02            0.000000                0.000000
# 14528            6.179144e-07            0.000000                0.000000
#
#        price_off_peak_var_max_diff  price_peak_var_max_diff  \
# 0                         0.028554                 0.000568
# 1                         0.001567                 0.085483
# 2                         0.000000                 0.001281
# 3                         0.000000                 0.000000
# 4                         0.001969                 0.001867
# ...                            ...                      ...
# 14524                     0.000569                 0.000000
# 14525                     0.000000                 0.000000
# 14526                     0.001969                 0.001867
# 14527                     0.001567                 0.085483
# 14528                     0.000000                 0.000000
#
#       price_mid_peak_var_max_diff  price_off_peak_fix_max_diff  \
# 0                        0.002337                     3.538045
# 1                        0.000000                     0.177780
# 2                        0.000000                     0.177779
# 3                        0.000000                     0.177779
# 4                        0.003541                     0.162916
# ...                           ...                          ...
# 14524                    0.000000                     0.177780
# 14525                    0.000260                     0.236688
# 14526                    0.003541                     0.162916
# 14527                    0.000000                     0.177780
# 14528                    0.000000                     0.000000
#
#        price_peak_fix_max_diff  price_mid_peak_fix_max_diff
# 0                     0.097752                     0.065172
# 1                     0.000000                     0.000000
# 2                     0.000000                     0.000000
# 3                     0.000000                     0.000000
# 4                     0.097749                     0.065166
# ...                        ...                          ...
# 14524                 0.000000                     0.000000
# 14525                 0.145968                     0.033468
# 14526                 0.097749                     0.065166
# 14527                 0.000000                     0.000000
# 14528                 0.000000                     0.000000
#
# [14529 rows x 56 columns]

# %% [markdown]
# ### Analysis of date variables

# %%
# 2. Create a table with min and max values for each date variable
datetime_cols = merged_df.select_dtypes(include=['datetime']).columns
date_summary = merged_df[datetime_cols].agg(['min', 'max']).transpose()
date_summary.columns = ['Minimum Date', 'Maximum Date']

# Display the results
print("Date Summary Table:")
date_summary
# Out:
# Date Summary Table:
#                 Minimum Date Maximum Date
# date_activ        2003-05-09   2014-09-01
# date_end          2016-01-28   2017-06-13
# date_modif_prod   2003-05-09   2016-01-29
# date_renewal      2013-06-26   2016-01-28

# %% [markdown]
# Before removing the date variables from the dataset, let's create some features out of them:
# - `product_modified`: this variable can take value 0 or 1, depending on whether `date_modif_prod` is equal to `date_activ` or not, respectively.
# - `contract_age_at_last_modif`: this variable represents the number of days between `date_activ` (contract activation date) and `date_modif_prod` (last product modification date), capturing how long it took for the product to be modified.
# - `days_to_end`: this variable computes the number of days between the end of the historical period (December 31, 2015) and the registered date of the end of the contract.

# %%
# Compute 'product_modified'
merged_df.loc[:, 'product_modified'] = (merged_df['date_modif_prod'] > merged_df['date_activ']).astype(int).astype('object')
merged_df.loc[:, 'product_modified'] = merged_df['product_modified'].map({0: 'No', 1: 'Yes'})

# Compute 'contract_age_at_last_modif'
merged_df.loc[:, 'contract_age_at_last_modif'] = (merged_df['date_modif_prod'] - merged_df['date_activ']).dt.days

# Compute 'days_to_end'
historical_end_date = pd.Timestamp('2015-12-31')
merged_df.loc[:, 'days_to_end'] = (merged_df['date_end'] - historical_end_date).dt.days

merged_df[['date_activ', 'date_modif_prod', 'product_modified', 'contract_age_at_last_modif', 'date_end', 'days_to_end']].head(10)
# Out:
#   date_activ date_modif_prod product_modified  contract_age_at_last_modif  \
# 0 2013-06-15      2015-11-01              Yes                         869
# 1 2009-08-21      2009-08-21               No                           0
# 2 2010-04-16      2010-04-16               No                           0
# 3 2010-03-30      2010-03-30               No                           0
# 4 2010-01-13      2010-01-13               No                           0
# 5 2011-12-09      2015-11-01              Yes                        1423
# 6 2011-12-02      2011-12-02               No                           0
# 7 2010-04-21      2010-04-21               No                           0
# 8 2011-09-23      2011-09-23               No                           0
# 9 2010-05-04      2015-04-29              Yes                        1821
#
#     date_end  days_to_end
# 0 2016-06-15          167
# 1 2016-08-30          243
# 2 2016-04-16          107
# 3 2016-03-30           90
# 4 2016-03-07           67
# 5 2016-12-09          344
# 6 2016-12-02          337
# 7 2016-04-21          112
# 8 2016-09-23          267
# 9 2016-05-04          125

# %%
merged_df.drop(datetime_cols, axis=1, inplace=True)

# %% [markdown]
# ### Saving the first version of the dataset

# %% [markdown]
# Before performing additional data transformations and feature engineerings on the numeric and categorical variables, it has been decided to save the current version of the dataset, in order to assess if the subsequent data preparation steps really enhance model performance.

# %%
merged_df.to_csv(f"{repo_path}/data/merged_data_no_tfm.csv", index=False)

# %% [markdown]
# ### Analysis of numeric variables

# %%
numeric_cols = merged_df.select_dtypes(include='number').columns

plot_numeric_distributions(merged_df, numeric_cols, n_cols=4)

# %% [markdown]
# As we can see, there are many extremely skewed predictors. This can be problematic because the number of observations available to predict the target varies greatly across the range of the input values. To have a better understanding of the problem, let's first compute skewness, number of 0s, and cardinality for each of the numeric columns:

# %%
num_stats_df = compute_and_sort_statistics(merged_df, numeric_cols, by='cardinality', ascending=True)
num_stats_df
# Out:
#                                  skewness  zero_counts  cardinality
# nb_prod_act                      8.665068            0           10
# forecast_discount_energy         5.145705        14018           12
# num_years_antig                  1.448207            0           13
# price_mid_peak_fix_min           0.636993         9384           13
# price_peak_fix_min               0.658660         9384           13
# price_mid_peak_fix_max           0.493465         8909           15
# price_peak_fix_max               0.514927         8909           16
# price_off_peak_fix_min          -5.748016          139           30
# price_peak_fix_max_diff          5.864831        10343           37
# price_off_peak_fix_max          -5.263687          105           39
# price_mid_peak_fix_max_diff      5.805980        10307           39
# forecast_price_pow_off_peak     -5.001835           94           41
# price_off_peak_fix_max_diff     15.344653         3158          111
# price_mid_peak_var_max           0.487314         8896          206
# price_peak_var_max              -0.168168         6330          314
# forecast_price_energy_peak      -0.015490         6979          327
# price_mid_peak_var_min           0.618774         9370          332
# price_mid_peak_fix_mean          0.510647         8909          336
# price_peak_fix_mean              0.532914         8909          336
# price_mid_peak_fix_std           5.777278         9651          351
# price_peak_fix_std               5.749277         9651          364
# days_to_end                     -0.042398            0          368
# price_peak_var_min              -0.010134         7040          449
# price_off_peak_var_max          -0.465978           20          497
# forecast_price_energy_off_peak  -0.130877           22          513
# price_off_peak_var_min          -1.683211           65          675
# price_mid_peak_var_max_diff      5.562554         9595          686
# pow_max                          5.787936            0          693
# price_off_peak_fix_mean         -5.377596          105          783
# price_off_peak_fix_std          14.920628         1386          879
# price_peak_var_max_diff          4.066029         8185          959
# price_off_peak_var_max_diff      6.717377         5306         1405
# contract_age_at_last_modif       0.990573         7248         1878
# price_mid_peak_var_std           5.419157         8967         1885
# price_mid_peak_var_mean          0.493274         8896         1899
# cons_gas_12m                     9.640002        11975         2059
# margin_net_pow_ele               4.475705          157         2381
# margin_gross_pow_ele             4.475003          157         2381
# price_peak_var_mean             -0.023956         6330         2686
# price_peak_var_std               4.221568         6330         2690
# forecast_meter_rent_12m          1.507597          722         3512
# forecast_cons_year              16.567187         6102         4210
# price_off_peak_var_mean         -0.908300           20         4624
# price_off_peak_var_std           6.414776          100         4653
# cons_last_month                  6.374610         4946         4740
# imp_cons                        13.183958         6124         7728
# cons_12m                         5.987711          116        11021
# net_margin                      36.540197          184        11917
# forecast_cons_12m                7.153735          305        13922

# %% [markdown]
# Let's focus on the first 3 variables of the table above (`forecast_discount_energy`, `nb_prod_act` and `num_years_antig`) and plot their value frequencies:

# %%
low_cardinality_cols = ['forecast_discount_energy', 'nb_prod_act', 'num_years_antig']

plot_bar_charts(merged_df, low_cardinality_cols, orientation='horizontal', ncols=3)

# %% [markdown]
# For these 3 variables, I decided to create the following categorical variables to group rare values and see if this might be helpful in reducing overfit and generalize better on unseen data:
# - `nb_prod_act`: 3 categories: '1', '2' and '3 or more'.
# - `num_years_antig`: 5 categories: '3 or less', '4', '5', '6' and '7 or more'.
# - `forecast_discount_energy`: in this case, since less than 4% of the data has a value different than 0, I decided to just create a flag with values '0' and '>0'.

# %%
# Transformation for `nb_prod_act`
merged_df['nb_prod_act_cat'] = np.where(merged_df['nb_prod_act'] >= 3, '3 or more',
                                        merged_df['nb_prod_act'].astype(str))

# Transformation for `num_years_antig`
merged_df['num_years_antig_cat'] = np.where(merged_df['num_years_antig'] <= 3, '3 or less',
                                        np.where(merged_df['num_years_antig'] == 4, '4',
                                                np.where(merged_df['num_years_antig'] == 5, '5',
                                                        np.where(merged_df['num_years_antig'] == 6, '6', '7 or more'))))

# Transformation for `forecast_discount_energy`
merged_df['is_zero_forecast_discount_energy'] = np.where(merged_df['forecast_discount_energy'] > 0, 'No', 'Yes')

# Remove the original variables
merged_df.drop(low_cardinality_cols, axis=1, inplace=True)

# %%
categorized_cols = ['nb_prod_act_cat', 'num_years_antig_cat', 'is_zero_forecast_discount_energy']

plot_bar_charts(merged_df, categorized_cols, orientation='vertical')

# %%
numeric_cols = [col for col in numeric_cols if col not in low_cardinality_cols]

num_stats_df = num_stats_df.loc[numeric_cols].sort_values(by='zero_counts', ascending=False)
num_stats_df
# Out:
#                                  skewness  zero_counts  cardinality
# cons_gas_12m                     9.640002        11975         2059
# price_peak_fix_max_diff          5.864831        10343           37
# price_mid_peak_fix_max_diff      5.805980        10307           39
# price_mid_peak_fix_std           5.777278         9651          351
# price_peak_fix_std               5.749277         9651          364
# price_mid_peak_var_max_diff      5.562554         9595          686
# price_peak_fix_min               0.658660         9384           13
# price_mid_peak_fix_min           0.636993         9384           13
# price_mid_peak_var_min           0.618774         9370          332
# price_mid_peak_var_std           5.419157         8967         1885
# price_mid_peak_fix_mean          0.510647         8909          336
# price_peak_fix_max               0.514927         8909           16
# price_mid_peak_fix_max           0.493465         8909           15
# price_peak_fix_mean              0.532914         8909          336
# price_mid_peak_var_mean          0.493274         8896         1899
# price_mid_peak_var_max           0.487314         8896          206
# price_peak_var_max_diff          4.066029         8185          959
# contract_age_at_last_modif       0.990573         7248         1878
# price_peak_var_min              -0.010134         7040          449
# forecast_price_energy_peak      -0.015490         6979          327
# price_peak_var_std               4.221568         6330         2690
# price_peak_var_max              -0.168168         6330          314
# price_peak_var_mean             -0.023956         6330         2686
# imp_cons                        13.183958         6124         7728
# forecast_cons_year              16.567187         6102         4210
# price_off_peak_var_max_diff      6.717377         5306         1405
# cons_last_month                  6.374610         4946         4740
# price_off_peak_fix_max_diff     15.344653         3158          111
# price_off_peak_fix_std          14.920628         1386          879
# forecast_meter_rent_12m          1.507597          722         3512
# forecast_cons_12m                7.153735          305        13922
# net_margin                      36.540197          184        11917
# margin_gross_pow_ele             4.475003          157         2381
# margin_net_pow_ele               4.475705          157         2381
# price_off_peak_fix_min          -5.748016          139           30
# cons_12m                         5.987711          116        11021
# price_off_peak_fix_max          -5.263687          105           39
# price_off_peak_fix_mean         -5.377596          105          783
# price_off_peak_var_std           6.414776          100         4653
# forecast_price_pow_off_peak     -5.001835           94           41
# price_off_peak_var_min          -1.683211           65          675
# forecast_price_energy_off_peak  -0.130877           22          513
# price_off_peak_var_max          -0.465978           20          497
# price_off_peak_var_mean         -0.908300           20         4624
# pow_max                          5.787936            0          693
# days_to_end                     -0.042398            0          368

# %% [markdown]
# There are several columns with many rows having value 0. Let's see the distributions of the variables with more than 30% of 0 values when removing all these 0 rows:

# %%
plot_histograms_for_sparse_cols(merged_df, numeric_cols, zero_threshold=0.3)
# Out:
# Skewness for column cons_gas_12m (excluding zeros): 3.912
# ---------------------------------
# Skewness for column cons_last_month (excluding zeros): 5.122
# ---------------------------------
# Skewness for column forecast_cons_year (excluding zeros): 14.926
# ---------------------------------
# Skewness for column forecast_price_energy_peak (excluding zeros): 2.198
# ---------------------------------
# Skewness for column imp_cons (excluding zeros): 11.923
# ---------------------------------
# Skewness for column price_peak_var_mean (excluding zeros): -2.447
# ---------------------------------
# Skewness for column price_mid_peak_var_mean (excluding zeros): -4.023
# ---------------------------------
# Skewness for column price_peak_fix_mean (excluding zeros): -0.139
# ---------------------------------
# Skewness for column price_mid_peak_fix_mean (excluding zeros): -4.341
# ---------------------------------
# Skewness for column price_peak_var_min (excluding zeros): 0.732
# ---------------------------------
# Skewness for column price_mid_peak_var_min (excluding zeros): 2.211
# ---------------------------------
# Skewness for column price_peak_fix_min (excluding zeros): 5.119
# ---------------------------------
# Skewness for column price_mid_peak_fix_min (excluding zeros): -5.093
# ---------------------------------
# Skewness for column price_peak_var_max (excluding zeros): 1.111
# ---------------------------------
# Skewness for column price_mid_peak_var_max (excluding zeros): 2.997
# ---------------------------------
# Skewness for column price_peak_fix_max (excluding zeros): 5.030
# ---------------------------------
# Skewness for column price_mid_peak_fix_max (excluding zeros): -4.989
# ---------------------------------
# Skewness for column price_peak_var_std (excluding zeros): 3.165
# ---------------------------------
# Skewness for column price_mid_peak_var_std (excluding zeros): 3.175
# ---------------------------------
# Skewness for column price_peak_fix_std (excluding zeros): 3.037
# ---------------------------------
# Skewness for column price_mid_peak_fix_std (excluding zeros): 3.056
# ---------------------------------
# Skewness for column price_off_peak_var_max_diff (excluding zeros): 5.356
# ---------------------------------
# Skewness for column price_peak_var_max_diff (excluding zeros): 2.403
# ---------------------------------
# Skewness for column price_mid_peak_var_max_diff (excluding zeros): 2.990
# ---------------------------------
# Skewness for column price_peak_fix_max_diff (excluding zeros): 2.808
# ---------------------------------
# Skewness for column price_mid_peak_fix_max_diff (excluding zeros): 2.789
# ---------------------------------
# Skewness for column contract_age_at_last_modif (excluding zeros): 0.992
# ---------------------------------

# %% [markdown]
# Some of these distributions remain highly skewed even when removing the 0 values. For all these variables, we can consider to build:
# - a flag indicator telling whether the variable is in the spike (0 value) or in the distribution (non-zero value).
# - a variable created from the values of the original one in the distribution and where the observations that have the value at the spike are set to missing. A log or square transformation (depending on whether the skewness is greater than 3 or lower than -3, respectively) is then performed on the non-missing values of this variable (except for the variables whose skewness is less than 3 when removing the 0 rows), while missing values will be imputed during the Model Building phase.

# %%
many_zeros_cols = [col for col in num_stats_df.index if num_stats_df.loc[col,'zero_counts']>0.3*len(merged_df)]

merged_df, distr_transformed_cols = engineer_saz_features(merged_df, many_zeros_cols, skewness_threshold=3.0)

# %%
merged_df.drop(many_zeros_cols, axis=1, inplace=True)

# %% [markdown]
# Let's now focus on the remaining numeric variables:

# %%
numeric_cols = [col for col in numeric_cols if col not in many_zeros_cols]

num_stats_df = num_stats_df.loc[numeric_cols].sort_values(by='skewness', ascending=False)
num_stats_df
# Out:
#                                  skewness  zero_counts  cardinality
# net_margin                      36.540197          184        11917
# price_off_peak_fix_max_diff     15.344653         3158          111
# price_off_peak_fix_std          14.920628         1386          879
# forecast_cons_12m                7.153735          305        13922
# price_off_peak_var_std           6.414776          100         4653
# cons_12m                         5.987711          116        11021
# pow_max                          5.787936            0          693
# margin_net_pow_ele               4.475705          157         2381
# margin_gross_pow_ele             4.475003          157         2381
# forecast_meter_rent_12m          1.507597          722         3512
# days_to_end                     -0.042398            0          368
# forecast_price_energy_off_peak  -0.130877           22          513
# price_off_peak_var_max          -0.465978           20          497
# price_off_peak_var_mean         -0.908300           20         4624
# price_off_peak_var_min          -1.683211           65          675
# forecast_price_pow_off_peak     -5.001835           94           41
# price_off_peak_fix_max          -5.263687          105           39
# price_off_peak_fix_mean         -5.377596          105          783
# price_off_peak_fix_min          -5.748016          139           30

# %% [markdown]
# For them, I decided to apply a log transformation to all remaining variables with a skewness greater than 3 and a square transformation to all remaining variables with a skewness lower than -3. This was done to achieve a more consistent distribution across their range of values, for the same reasons mentioned earlier.

# %%
skewness = num_stats_df['skewness']
cols_to_transform = [col for col in num_stats_df.index if abs(skewness[col])>3]
transformed_cols = []

for col in cols_to_transform:
    if skewness[col]<0:
        col_name = f"{col}_square"
        merged_df[col_name] = merged_df[col].apply(lambda x: x**2)
    elif skewness[col]>0:
        col_name = f"{col}_log"
        merged_df[col_name] = merged_df[col].apply(lambda x: np.log1p(x))

    transformed_cols.append(col_name)

# Print the transformed columns
print(f"Transformed columns: {cols_to_transform}")
# Out:
# Transformed columns: ['net_margin', 'price_off_peak_fix_max_diff', 'price_off_peak_fix_std', 'forecast_cons_12m', 'price_off_peak_var_std', 'cons_12m', 'pow_max', 'margin_net_pow_ele', 'margin_gross_pow_ele', 'forecast_price_pow_off_peak', 'price_off_peak_fix_max', 'price_off_peak_fix_mean', 'price_off_peak_fix_min']

# %%
merged_df.drop(cols_to_transform, axis=1, inplace=True)

# %% [markdown]
# Let's now conclude the data preparation phase by examining the categorical variables.

# %% [markdown]
# ### Categorical variables

# %%
categorical_cols = [col for col in merged_df.select_dtypes(exclude='number').columns if col!='id']
categorical_cols
# Out:
# ['channel_sales',
#  'has_gas',
#  'origin_up',
#  'churn',
#  'product_modified',
#  'nb_prod_act_cat',
#  'num_years_antig_cat',
#  'is_zero_forecast_discount_energy',
#  'is_zero_cons_gas_12m',
#  'is_zero_price_peak_fix_max_diff',
#  'is_zero_price_mid_peak_fix_max_diff',
#  'is_zero_price_mid_peak_fix_std',
#  'is_zero_price_peak_fix_std',
#  'is_zero_price_mid_peak_var_max_diff',
#  'is_zero_price_peak_fix_min',
#  'is_zero_price_mid_peak_fix_min',
#  'is_zero_price_mid_peak_var_min',
#  'is_zero_price_mid_peak_var_std',
#  'is_zero_price_mid_peak_fix_mean',
#  'is_zero_price_peak_fix_max',
#  'is_zero_price_mid_peak_fix_max',
#  'is_zero_price_peak_fix_mean',
#  'is_zero_price_mid_peak_var_mean',
#  'is_zero_price_mid_peak_var_max',
#  'is_zero_price_peak_var_max_diff',
#  'is_zero_contract_age_at_last_modif',
#  'is_zero_price_peak_var_min',
#  'is_zero_forecast_price_energy_peak',
#  'is_zero_price_peak_var_std',
#  'is_zero_price_peak_var_max',
#  'is_zero_price_peak_var_mean',
#  'is_zero_imp_cons',
#  'is_zero_forecast_cons_year',
#  'is_zero_price_off_peak_var_max_diff',
#  'is_zero_cons_last_month']

# %%
plot_bar_charts(merged_df, categorical_cols, sort_index=False, ncols=4)

# %% [markdown]
# As you can see, some categories are very poorly represented:
#
# - `'Channel 5'`, `'Channel 6'` and `'Channel 7'` for the `channel_sales` variable
# - `'Campaign 4'`, `'Campaign 5'` and `'Campaign Missing'` for the `origin_up` variable
#
# Since these categories are underrepresented, they are likely to introduce noise into the data without providing sufficient examples to learn meaningful patterns. Therefore, I decided to remove the rows corresponding to categories that account for less than 1% of the total observations.

# %%
merged_df = remove_underrepresented_categories(merged_df, categorical_cols)
# Out:
# Removed categories from 'channel_sales':
#   - Channel 6
#   - Channel 5
#   - Channel 7
#
# Removed categories from 'origin_up':
#   - Campaign Missing
#   - Campaign 4
#   - Campaign 5

# %% [markdown]
# ### Removing highly correlated variables

# %% [markdown]
# Let's plot the **correlation matrix** for the numeric variables, displaying only cells with a correlation greater than 0.9:

# %%
high_corr_pairs = plot_correlation_matrix(merged_df, merged_df.select_dtypes(include='number').columns)
high_corr_pairs.sort_values(by="correlation", ascending=False)
# Out:
#                               variable_1                          variable_2  \
# 1020              margin_net_pow_ele_log            margin_gross_pow_ele_log
# 506               price_peak_fix_min_log       price_off_peak_fix_min_square
# 509        price_mid_peak_fix_min_square      price_mid_peak_fix_mean_square
# 505               price_peak_fix_min_log      price_off_peak_fix_mean_square
# 480               price_peak_fix_min_log           price_peak_fix_mean_distr
# 504               price_peak_fix_min_log       price_off_peak_fix_max_square
# 369           price_mid_peak_fix_std_log              price_peak_fix_std_log
# 503               price_peak_fix_min_log  forecast_price_pow_off_peak_square
# 478               price_peak_fix_min_log              price_peak_fix_max_log
# 511        price_mid_peak_fix_min_square       price_mid_peak_fix_max_square
# 655               price_peak_fix_max_log      price_off_peak_fix_mean_square
# 899                         imp_cons_log              forecast_cons_year_log
# 653               price_peak_fix_max_log  forecast_price_pow_off_peak_square
# 1032       price_off_peak_fix_max_square      price_off_peak_fix_mean_square
# 294        price_peak_fix_max_diff_distr   price_mid_peak_fix_max_diff_distr
# 654               price_peak_fix_max_log       price_off_peak_fix_max_square
# 90               price_off_peak_var_mean              price_off_peak_var_max
# 334    price_mid_peak_fix_max_diff_distr   price_mid_peak_var_max_diff_distr
# 297        price_peak_fix_max_diff_distr   price_mid_peak_var_max_diff_distr
# 1030  forecast_price_pow_off_peak_square      price_off_peak_fix_mean_square
# 1029  forecast_price_pow_off_peak_square       price_off_peak_fix_max_square
# 374           price_mid_peak_fix_std_log          price_mid_peak_var_std_log
# 45        forecast_price_energy_off_peak             price_off_peak_var_mean
# 332    price_mid_peak_fix_max_diff_distr          price_mid_peak_fix_std_log
# 296        price_peak_fix_max_diff_distr              price_peak_fix_std_log
# 409               price_peak_fix_std_log          price_mid_peak_var_std_log
# 1034      price_off_peak_fix_mean_square       price_off_peak_fix_min_square
# 333    price_mid_peak_fix_max_diff_distr              price_peak_fix_std_log
# 740         price_mid_peak_var_max_distr            price_peak_var_max_distr
# 47        forecast_price_energy_off_peak              price_off_peak_var_max
# 826     forecast_price_energy_peak_distr            price_peak_var_max_distr
# 295        price_peak_fix_max_diff_distr          price_mid_peak_fix_std_log
# 762        price_peak_var_max_diff_distr              price_peak_var_std_log
# 969      price_off_peak_fix_max_diff_log          price_off_peak_fix_std_log
# 949                  cons_last_month_log                        cons_12m_log
# 89               price_off_peak_var_mean              price_off_peak_var_min
# 405               price_peak_fix_std_log   price_mid_peak_var_max_diff_distr
# 443    price_mid_peak_var_max_diff_distr          price_mid_peak_var_std_log
# 935      price_off_peak_var_max_diff_log          price_off_peak_var_std_log
# 370           price_mid_peak_fix_std_log   price_mid_peak_var_max_diff_distr
# 738         price_mid_peak_var_max_distr    forecast_price_energy_peak_distr
# 681        price_mid_peak_fix_max_square       price_off_peak_fix_max_square
# 629               price_peak_fix_max_log       price_mid_peak_fix_max_square
# 680        price_mid_peak_fix_max_square  forecast_price_pow_off_peak_square
# 682        price_mid_peak_fix_max_square      price_off_peak_fix_mean_square
# 479               price_peak_fix_min_log       price_mid_peak_fix_max_square
# 535        price_mid_peak_fix_min_square  forecast_price_pow_off_peak_square
# 477               price_peak_fix_min_log      price_mid_peak_fix_mean_square
# 474               price_peak_fix_min_log       price_mid_peak_fix_min_square
# 510        price_mid_peak_fix_min_square              price_peak_fix_max_log
# 538        price_mid_peak_fix_min_square       price_off_peak_fix_min_square
# 512        price_mid_peak_fix_min_square           price_peak_fix_mean_distr
# 536        price_mid_peak_fix_min_square       price_off_peak_fix_max_square
# 537        price_mid_peak_fix_min_square      price_off_peak_fix_mean_square
#
#       correlation
# 1020     0.999892
# 506      0.999798
# 509      0.999109
# 505      0.997273
# 480      0.997244
# 504      0.995960
# 369      0.995247
# 503      0.993943
# 478      0.993608
# 511      0.988185
# 655      0.987745
# 899      0.986580
# 653      0.985748
# 1032     0.977617
# 294      0.976892
# 654      0.966891
# 90       0.965228
# 334      0.960373
# 297      0.959135
# 1030     0.957392
# 1029     0.951870
# 374      0.951365
# 45       0.950854
# 332      0.949695
# 296      0.949562
# 409      0.948711
# 1034     0.944269
# 333      0.943586
# 740      0.942357
# 47       0.935697
# 826      0.935695
# 295      0.934617
# 762      0.932756
# 969      0.922412
# 949      0.920485
# 89       0.917549
# 405      0.910330
# 443      0.909118
# 935      0.907699
# 370      0.907387
# 738      0.902884
# 681     -0.948928
# 629     -0.970746
# 680     -0.974810
# 682     -0.976692
# 479     -0.987161
# 535     -0.988349
# 477     -0.991967
# 474     -0.992072
# 510     -0.992410
# 538     -0.993797
# 512     -0.995669
# 536     -0.996456
# 537     -0.996852

# %% [markdown]
# As you can see, several pairs of variables exhibit a high correlation (greater than 0.9), meaning they convey nearly the same information. To reduce redundancy, we applied the custom `process_graph` function, which iteratively removes variables based on their connectivity in the correlation graph. Specifically, within each connected component of highly correlated variables, the function removes nodes (variables) with the highest number of connections, prioritizing those with the strongest correlations. The process continues until no strongly correlated pairs remain, ensuring that only the most representative variables are retained.

# %%
variables_to_remove = process_graph(high_corr_pairs)
# Out:
# Initial graph:
# Graph with 35 nodes and 54 edges
# The graph is made of the following components:
# 1) {'price_off_peak_var_min', 'forecast_price_energy_off_peak', 'price_off_peak_var_mean', 'price_off_peak_var_max'}
# 2) {'price_mid_peak_fix_max_diff_distr', 'price_peak_fix_max_diff_distr', 'price_mid_peak_var_max_diff_distr', 'price_peak_fix_std_log', 'price_mid_peak_var_std_log', 'price_mid_peak_fix_std_log'}
# 3) {'price_peak_fix_max_log', 'price_mid_peak_fix_max_square', 'price_off_peak_fix_max_square', 'forecast_price_pow_off_peak_square', 'price_mid_peak_fix_min_square', 'price_off_peak_fix_min_square', 'price_peak_fix_mean_distr', 'price_mid_peak_fix_mean_square', 'price_off_peak_fix_mean_square', 'price_peak_fix_min_log'}
# 4) {'price_peak_var_max_distr', 'price_mid_peak_var_max_distr', 'forecast_price_energy_peak_distr'}
# 5) {'price_peak_var_std_log', 'price_peak_var_max_diff_distr'}
# 6) {'imp_cons_log', 'forecast_cons_year_log'}
# 7) {'price_off_peak_var_std_log', 'price_off_peak_var_max_diff_log'}
# 8) {'cons_last_month_log', 'cons_12m_log'}
# 9) {'price_off_peak_fix_std_log', 'price_off_peak_fix_max_diff_log'}
# 10) {'margin_net_pow_ele_log', 'margin_gross_pow_ele_log'}
# Let's see if there's something to do for the component n. 1:
# Graph with 4 nodes and 4 edges
# The candidate nodes to remove (highest number of arcs) are the following:
# ['price_off_peak_var_mean']
# Let's remove node price_off_peak_var_mean
# Graph after price_off_peak_var_mean removal
# Graph with 34 nodes and 51 edges
# -------------------------------------
# Let's see if there's something to do for the component n. 2:
# Graph with 6 nodes and 13 edges
# The candidate nodes to remove (highest number of arcs) are the following:
# ['price_mid_peak_var_max_diff_distr', 'price_peak_fix_std_log', 'price_mid_peak_fix_std_log']
# ['price_mid_peak_fix_std_log', 'price_peak_fix_std_log', 'price_mid_peak_var_max_diff_distr']
# Let's remove node price_mid_peak_fix_std_log
# Graph after price_mid_peak_fix_std_log removal
# Graph with 33 nodes and 46 edges
# -------------------------------------
# Let's see if there's something to do for the component n. 3:
# Graph with 10 nodes and 28 edges
# The candidate nodes to remove (highest number of arcs) are the following:
# ['price_mid_peak_fix_min_square', 'price_peak_fix_min_log']
# ['price_peak_fix_min_log', 'price_mid_peak_fix_min_square']
# Let's remove node price_peak_fix_min_log
# Graph after price_peak_fix_min_log removal
# Graph with 32 nodes and 37 edges
# -------------------------------------
# Let's see if there's something to do for the component n. 4:
# Graph with 3 nodes and 3 edges
# The candidate nodes to remove (highest number of arcs) are the following:
# ['price_peak_var_max_distr', 'price_mid_peak_var_max_distr', 'forecast_price_energy_peak_distr']
# ['price_peak_var_max_distr', 'price_mid_peak_var_max_distr', 'forecast_price_energy_peak_distr']
# Let's remove node price_peak_var_max_distr
# Graph after price_peak_var_max_distr removal
# Graph with 31 nodes and 35 edges
# -------------------------------------
# Let's see if there's something to do for the component n. 5:
# Graph with 2 nodes and 1 edges
# The candidate nodes to remove (highest number of arcs) are the following:
# ['price_peak_var_std_log', 'price_peak_var_max_diff_distr']
# ['price_peak_var_max_diff_distr', 'price_peak_var_std_log']
# Let's remove node price_peak_var_max_diff_distr
# Graph after price_peak_var_max_diff_distr removal
# Graph with 30 nodes and 34 edges
# -------------------------------------
# Let's see if there's something to do for the component n. 6:
# Graph with 2 nodes and 1 edges
# The candidate nodes to remove (highest number of arcs) are the following:
# ['imp_cons_log', 'forecast_cons_year_log']
# ['forecast_cons_year_log', 'imp_cons_log']
# Let's remove node forecast_cons_year_log
# Graph after forecast_cons_year_log removal
# Graph with 29 nodes and 33 edges
# -------------------------------------
# Let's see if there's something to do for the component n. 7:
# Graph with 2 nodes and 1 edges
# The candidate nodes to remove (highest number of arcs) are the following:
# ['price_off_peak_var_std_log', 'price_off_peak_var_max_diff_log']
# ['price_off_peak_var_max_diff_log', 'price_off_peak_var_std_log']
# Let's remove node price_off_peak_var_max_diff_log
# Graph after price_off_peak_var_max_diff_log removal
# Graph with 28 nodes and 32 edges
# -------------------------------------
# Let's see if there's something to do for the component n. 8:
# Graph with 2 nodes and 1 edges
# The candidate nodes to remove (highest number of arcs) are the following:
# ['cons_last_month_log', 'cons_12m_log']
# ['cons_12m_log', 'cons_last_month_log']
# Let's remove node cons_12m_log
# Graph after cons_12m_log removal
# Graph with 27 nodes and 31 edges
# -------------------------------------
# Let's see if there's something to do for the component n. 9:
# Graph with 2 nodes and 1 edges
# The candidate nodes to remove (highest number of arcs) are the following:
# ['price_off_peak_fix_std_log', 'price_off_peak_fix_max_diff_log']
# ['price_off_peak_fix_max_diff_log', 'price_off_peak_fix_std_log']
# Let's remove node price_off_peak_fix_max_diff_log
# Graph after price_off_peak_fix_max_diff_log removal
# Graph with 26 nodes and 30 edges
# -------------------------------------
# Let's see if there's something to do for the component n. 10:
# Graph with 2 nodes and 1 edges
# The candidate nodes to remove (highest number of arcs) are the following:
# ['margin_net_pow_ele_log', 'margin_gross_pow_ele_log']
# ['margin_gross_pow_ele_log', 'margin_net_pow_ele_log']
# Let's remove node margin_gross_pow_ele_log
# Graph after margin_gross_pow_ele_log removal
# Graph with 25 nodes and 29 edges
# -------------------------------------
# The graph is made of the following components:
# 1) {'forecast_price_energy_off_peak', 'price_off_peak_var_max'}
# 2) {'price_off_peak_var_min'}
# 3) {'price_mid_peak_fix_max_diff_distr', 'price_peak_fix_max_diff_distr', 'price_mid_peak_var_max_diff_distr', 'price_peak_fix_std_log', 'price_mid_peak_var_std_log'}
# 4) {'price_peak_fix_max_log', 'price_mid_peak_fix_max_square', 'price_off_peak_fix_max_square', 'forecast_price_pow_off_peak_square', 'price_mid_peak_fix_min_square', 'price_off_peak_fix_min_square', 'price_peak_fix_mean_distr', 'price_mid_peak_fix_mean_square', 'price_off_peak_fix_mean_square'}
# 5) {'price_mid_peak_var_max_distr', 'forecast_price_energy_peak_distr'}
# 6) {'price_peak_var_std_log'}
# 7) {'imp_cons_log'}
# 8) {'price_off_peak_var_std_log'}
# 9) {'cons_last_month_log'}
# 10) {'price_off_peak_fix_std_log'}
# 11) {'margin_net_pow_ele_log'}
# Let's see if there's something to do for the component n. 1:
# Graph with 2 nodes and 1 edges
# The candidate nodes to remove (highest number of arcs) are the following:
# ['forecast_price_energy_off_peak', 'price_off_peak_var_max']
# ['forecast_price_energy_off_peak', 'price_off_peak_var_max']
# Let's remove node forecast_price_energy_off_peak
# Graph after forecast_price_energy_off_peak removal
# Graph with 24 nodes and 28 edges
# -------------------------------------
# Let's see if there's something to do for the component n. 2:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 3:
# Graph with 5 nodes and 8 edges
# The candidate nodes to remove (highest number of arcs) are the following:
# ['price_mid_peak_var_max_diff_distr', 'price_peak_fix_std_log']
# ['price_mid_peak_var_max_diff_distr', 'price_peak_fix_std_log']
# Let's remove node price_mid_peak_var_max_diff_distr
# Graph after price_mid_peak_var_max_diff_distr removal
# Graph with 23 nodes and 24 edges
# -------------------------------------
# Let's see if there's something to do for the component n. 4:
# Graph with 9 nodes and 19 edges
# The candidate nodes to remove (highest number of arcs) are the following:
# ['price_mid_peak_fix_min_square']
# Let's remove node price_mid_peak_fix_min_square
# Graph after price_mid_peak_fix_min_square removal
# Graph with 22 nodes and 16 edges
# -------------------------------------
# Let's see if there's something to do for the component n. 5:
# Graph with 2 nodes and 1 edges
# The candidate nodes to remove (highest number of arcs) are the following:
# ['price_mid_peak_var_max_distr', 'forecast_price_energy_peak_distr']
# ['forecast_price_energy_peak_distr', 'price_mid_peak_var_max_distr']
# Let's remove node forecast_price_energy_peak_distr
# Graph after forecast_price_energy_peak_distr removal
# Graph with 21 nodes and 15 edges
# -------------------------------------
# Let's see if there's something to do for the component n. 6:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 7:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 8:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 9:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 10:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 11:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# The graph is made of the following components:
# 1) {'price_off_peak_var_max'}
# 2) {'price_off_peak_var_min'}
# 3) {'price_mid_peak_fix_max_diff_distr', 'price_peak_fix_std_log', 'price_peak_fix_max_diff_distr', 'price_mid_peak_var_std_log'}
# 4) {'price_mid_peak_fix_mean_square'}
# 5) {'price_peak_fix_max_log', 'price_mid_peak_fix_max_square', 'price_off_peak_fix_max_square', 'forecast_price_pow_off_peak_square', 'price_off_peak_fix_min_square', 'price_off_peak_fix_mean_square'}
# 6) {'price_peak_fix_mean_distr'}
# 7) {'price_mid_peak_var_max_distr'}
# 8) {'price_peak_var_std_log'}
# 9) {'imp_cons_log'}
# 10) {'price_off_peak_var_std_log'}
# 11) {'cons_last_month_log'}
# 12) {'price_off_peak_fix_std_log'}
# 13) {'margin_net_pow_ele_log'}
# Let's see if there's something to do for the component n. 1:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 2:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 3:
# Graph with 4 nodes and 4 edges
# The candidate nodes to remove (highest number of arcs) are the following:
# ['price_peak_fix_std_log']
# Let's remove node price_peak_fix_std_log
# Graph after price_peak_fix_std_log removal
# Graph with 20 nodes and 12 edges
# -------------------------------------
# Let's see if there's something to do for the component n. 4:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 5:
# Graph with 6 nodes and 11 edges
# The candidate nodes to remove (highest number of arcs) are the following:
# ['price_off_peak_fix_mean_square']
# Let's remove node price_off_peak_fix_mean_square
# Graph after price_off_peak_fix_mean_square removal
# Graph with 19 nodes and 7 edges
# -------------------------------------
# Let's see if there's something to do for the component n. 6:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 7:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 8:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 9:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 10:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 11:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 12:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 13:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# The graph is made of the following components:
# 1) {'price_off_peak_var_max'}
# 2) {'price_off_peak_var_min'}
# 3) {'price_mid_peak_fix_max_diff_distr', 'price_peak_fix_max_diff_distr'}
# 4) {'price_mid_peak_var_std_log'}
# 5) {'price_mid_peak_fix_mean_square'}
# 6) {'price_peak_fix_max_log', 'price_mid_peak_fix_max_square', 'forecast_price_pow_off_peak_square', 'price_off_peak_fix_max_square'}
# 7) {'price_peak_fix_mean_distr'}
# 8) {'price_off_peak_fix_min_square'}
# 9) {'price_mid_peak_var_max_distr'}
# 10) {'price_peak_var_std_log'}
# 11) {'imp_cons_log'}
# 12) {'price_off_peak_var_std_log'}
# 13) {'cons_last_month_log'}
# 14) {'price_off_peak_fix_std_log'}
# 15) {'margin_net_pow_ele_log'}
# Let's see if there's something to do for the component n. 1:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 2:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 3:
# Graph with 2 nodes and 1 edges
# The candidate nodes to remove (highest number of arcs) are the following:
# ['price_mid_peak_fix_max_diff_distr', 'price_peak_fix_max_diff_distr']
# ['price_mid_peak_fix_max_diff_distr', 'price_peak_fix_max_diff_distr']
# Let's remove node price_mid_peak_fix_max_diff_distr
# Graph after price_mid_peak_fix_max_diff_distr removal
# Graph with 18 nodes and 6 edges
# -------------------------------------
# Let's see if there's something to do for the component n. 4:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 5:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 6:
# Graph with 4 nodes and 6 edges
# The candidate nodes to remove (highest number of arcs) are the following:
# ['price_peak_fix_max_log', 'price_mid_peak_fix_max_square', 'forecast_price_pow_off_peak_square', 'price_off_peak_fix_max_square']
# ['price_peak_fix_max_log', 'forecast_price_pow_off_peak_square', 'price_off_peak_fix_max_square', 'price_mid_peak_fix_max_square']
# Let's remove node price_peak_fix_max_log
# Graph after price_peak_fix_max_log removal
# Graph with 17 nodes and 3 edges
# -------------------------------------
# Let's see if there's something to do for the component n. 7:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 8:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 9:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 10:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 11:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 12:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 13:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 14:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 15:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# The graph is made of the following components:
# 1) {'price_off_peak_var_max'}
# 2) {'price_off_peak_var_min'}
# 3) {'price_peak_fix_max_diff_distr'}
# 4) {'price_mid_peak_var_std_log'}
# 5) {'price_mid_peak_fix_mean_square'}
# 6) {'price_off_peak_fix_max_square', 'price_mid_peak_fix_max_square', 'forecast_price_pow_off_peak_square'}
# 7) {'price_peak_fix_mean_distr'}
# 8) {'price_off_peak_fix_min_square'}
# 9) {'price_mid_peak_var_max_distr'}
# 10) {'price_peak_var_std_log'}
# 11) {'imp_cons_log'}
# 12) {'price_off_peak_var_std_log'}
# 13) {'cons_last_month_log'}
# 14) {'price_off_peak_fix_std_log'}
# 15) {'margin_net_pow_ele_log'}
# Let's see if there's something to do for the component n. 1:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 2:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 3:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 4:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 5:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 6:
# Graph with 3 nodes and 3 edges
# The candidate nodes to remove (highest number of arcs) are the following:
# ['price_off_peak_fix_max_square', 'price_mid_peak_fix_max_square', 'forecast_price_pow_off_peak_square']
# ['price_off_peak_fix_max_square', 'forecast_price_pow_off_peak_square', 'price_mid_peak_fix_max_square']
# Let's remove node price_off_peak_fix_max_square
# Graph after price_off_peak_fix_max_square removal
# Graph with 16 nodes and 1 edges
# -------------------------------------
# Let's see if there's something to do for the component n. 7:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 8:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 9:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 10:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 11:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 12:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 13:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 14:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 15:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# The graph is made of the following components:
# 1) {'price_off_peak_var_max'}
# 2) {'price_off_peak_var_min'}
# 3) {'price_peak_fix_max_diff_distr'}
# 4) {'price_mid_peak_var_std_log'}
# 5) {'price_mid_peak_fix_mean_square'}
# 6) {'price_mid_peak_fix_max_square', 'forecast_price_pow_off_peak_square'}
# 7) {'price_peak_fix_mean_distr'}
# 8) {'price_off_peak_fix_min_square'}
# 9) {'price_mid_peak_var_max_distr'}
# 10) {'price_peak_var_std_log'}
# 11) {'imp_cons_log'}
# 12) {'price_off_peak_var_std_log'}
# 13) {'cons_last_month_log'}
# 14) {'price_off_peak_fix_std_log'}
# 15) {'margin_net_pow_ele_log'}
# Let's see if there's something to do for the component n. 1:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 2:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 3:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 4:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 5:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 6:
# Graph with 2 nodes and 1 edges
# The candidate nodes to remove (highest number of arcs) are the following:
# ['price_mid_peak_fix_max_square', 'forecast_price_pow_off_peak_square']
# ['forecast_price_pow_off_peak_square', 'price_mid_peak_fix_max_square']
# Let's remove node forecast_price_pow_off_peak_square
# Graph after forecast_price_pow_off_peak_square removal
# Graph with 15 nodes and 0 edges
# -------------------------------------
# Let's see if there's something to do for the component n. 7:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 8:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 9:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 10:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 11:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 12:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 13:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 14:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# Let's see if there's something to do for the component n. 15:
# Graph with 1 nodes and 0 edges
# I found a component with only one node, nothing to do with it :)
# -------------------------------------
# The graph is made of the following components:
# 1) {'price_off_peak_var_max'}
# 2) {'price_off_peak_var_min'}
# 3) {'price_peak_fix_max_diff_distr'}
# 4) {'price_mid_peak_var_std_log'}
# 5) {'price_mid_peak_fix_mean_square'}
# 6) {'price_mid_peak_fix_max_square'}
# 7) {'price_peak_fix_mean_distr'}
# 8) {'price_off_peak_fix_min_square'}
# 9) {'price_mid_peak_var_max_distr'}
# 10) {'price_peak_var_std_log'}
# 11) {'imp_cons_log'}
# 12) {'price_off_peak_var_std_log'}
# 13) {'cons_last_month_log'}
# 14) {'price_off_peak_fix_std_log'}
# 15) {'margin_net_pow_ele_log'}
# There are no remaining arcs, we are done!
# Final disconnected graph:
# Graph with 15 nodes and 0 edges
# Variables to remove: ['price_off_peak_var_mean', 'price_mid_peak_fix_std_log', 'price_peak_fix_min_log', 'price_peak_var_max_distr', 'price_peak_var_max_diff_distr', 'forecast_cons_year_log', 'price_off_peak_var_max_diff_log', 'cons_12m_log', 'price_off_peak_fix_max_diff_log', 'margin_gross_pow_ele_log', 'forecast_price_energy_off_peak', 'price_mid_peak_var_max_diff_distr', 'price_mid_peak_fix_min_square', 'forecast_price_energy_peak_distr', 'price_peak_fix_std_log', 'price_off_peak_fix_mean_square', 'price_mid_peak_fix_max_diff_distr', 'price_peak_fix_max_log', 'price_off_peak_fix_max_square', 'forecast_price_pow_off_peak_square']

# %%
print("Variables to remove:", variables_to_remove)
print("Pre-removal shape:", merged_df.shape)
merged_df.drop(variables_to_remove, axis=1, inplace=True)
print("Post-removal shape:", merged_df.shape)

merged_df.to_csv(f"{repo_path}/data/merged_data_tfm.csv", index=False)

# %% [markdown]
# Finally, let's apply the same process to the table previously saved in the `merged_data_no_tfm.csv` file and update its content accordingly:

# %%
merged_no_tfm_df = pd.read_csv(f"{repo_path}/data/merged_data_no_tfm.csv")

high_corr_pairs = plot_correlation_matrix(merged_no_tfm_df, merged_no_tfm_df.select_dtypes(include='number').columns)
high_corr_pairs.sort_values(by="correlation", ascending=False)

# %%
variables_to_remove = process_graph(high_corr_pairs)

# %%
print("Variables to remove:", variables_to_remove)
print("Pre-removal shape:", merged_no_tfm_df.shape)
merged_no_tfm_df.drop(variables_to_remove, axis=1, inplace=True)
print("Post-removal shape:", merged_no_tfm_df.shape)

merged_no_tfm_df.to_csv(f"{repo_path}/data/merged_data_no_tfm.csv", index=False)
